# %%
import numpy as np
from google.colab import drive
import re
import pandas as pd

# %%
#mounting drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import random
import string

def specific_string(string, length):  
    sample_string = string # define the specific string  
    # define the condition for random string  
    result = "".join((random.choice(sample_string)) for x in range(length))  
    return result

# %%
homekey={}
left={}
right={}
middle={}
home= {}
for i in range(10):
    home.setdefault("0", []).append(specific_string("asdf",4))
    home.setdefault("0", []).append(specific_string("asdf",2))
    home.setdefault("0", []).append(specific_string("asdf",1))
    home.setdefault("0", []).append(specific_string("sadf",2))
    home.setdefault("0", []).append(specific_string("asdf",2))
    home.setdefault("0", []).append(specific_string("safd",2))
    home.setdefault("0", []).append(specific_string("adsf",3)) 
    home.setdefault("0", []).append(specific_string("asfd",3)) 
    home.setdefault("0", []).append(specific_string("afds",4))
    home.setdefault("0", []).append(specific_string("dsfa",4))
    
    home.setdefault("1", []).append(specific_string(";lkj",1))
    home.setdefault("1", []).append(specific_string("jkl;",1))  
    home.setdefault("1", []).append(specific_string("lkj;",3)) 
    home.setdefault("1", []).append(specific_string("jkl;",2))
    home.setdefault("1", []).append(specific_string("jkl;",4))
    home.setdefault("1", []).append(specific_string("jkl;",1))
    home.setdefault("1", []).append(specific_string("jkl;",4))
    home.setdefault("1", []).append(specific_string("jkl;",4))
    home.setdefault("1", []).append(specific_string("jkl;",2))
    home.setdefault("1", []).append(specific_string("jkl;",4))

    home.setdefault("2", []).append(specific_string("fghj",1))  
    home.setdefault("2", []).append(specific_string("fghj",2)) 
    home.setdefault("2", []).append(specific_string("jhgf",3))
    home.setdefault("2", []).append(specific_string("jhfg",4))
    home.setdefault("2", []).append(specific_string("hgfj",1))  
    home.setdefault("2", []).append(specific_string("ghjf",2)) 
    home.setdefault("2", []).append(specific_string("ghfj",3))
    home.setdefault("2", []).append(specific_string("jhgf",4))
    home.setdefault("2", []).append(specific_string("ghjf",3))
    home.setdefault("2", []).append(specific_string("fghj",4))

    home.setdefault("3", []).append(specific_string("asdfghjkl;",1))  
    home.setdefault("3", []).append(specific_string("asdfghjkl;",2)) 
    home.setdefault("3", []).append(specific_string("asdfghjkl;",3))
    home.setdefault("3", []).append(specific_string("asdfghjkl;",4))
    home.setdefault("3", []).append(specific_string("asdfghjkl;",1))  
    home.setdefault("3", []).append(specific_string("asdfghjkl;",2)) 
    home.setdefault("3", []).append(specific_string("asdfghjkl;",3))
    home.setdefault("3", []).append(specific_string("asdfghjkl;",4))
    home.setdefault("3", []).append(specific_string("asdfghjkl;",3))
    home.setdefault("3", []).append(specific_string("asdfghjkl;",4))


homekey=dict({'homekey':home})

# %%
bottomkey={}
left={}
right={}
middle={}
bottom= {}
for i in range(10):
    bottom.setdefault("0", []).append(specific_string("zxcv",1)) 
    bottom.setdefault("0", []).append(specific_string("zxcv",2)) 
    bottom.setdefault("0", []).append(specific_string("zxcv",3)) 
    bottom.setdefault("0", []).append(specific_string("zxcv",4))
    bottom.setdefault("0", []).append(specific_string("zxcv",1)) 
    bottom.setdefault("0", []).append(specific_string("zxcv",2)) 
    bottom.setdefault("0", []).append(specific_string("zxcv",3)) 
    bottom.setdefault("0", []).append(specific_string("zxcv",4))
    bottom.setdefault("0", []).append(specific_string("zxcv",3)) 
    bottom.setdefault("0", []).append(specific_string("zxcv",4)) 
 
    bottom.setdefault("1", []).append(specific_string(".,m/",1)) 
    bottom.setdefault("1", []).append(specific_string(".,m/",2)) 
    bottom.setdefault("1", []).append(specific_string(".,m/",3)) 
    bottom.setdefault("1", []).append(specific_string(".,m/",4)) 
    bottom.setdefault("1", []).append(specific_string(".,m/",1)) 
    bottom.setdefault("1", []).append(specific_string(".,m/",2)) 
    bottom.setdefault("1", []).append(specific_string(".,m/",3)) 
    bottom.setdefault("1", []).append(specific_string(".,m/",4))  
    bottom.setdefault("1", []).append(specific_string(".,m/",1)) 
    bottom.setdefault("1", []).append(specific_string(".,m/",2)) 
    bottom.setdefault("1", []).append(specific_string(".,m/",3)) 
    bottom.setdefault("1", []).append(specific_string(".,m/",4)) 

    bottom.setdefault("2", []).append(specific_string("cvbn",1)) 
    bottom.setdefault("2", []).append(specific_string("nbcv",2)) 
    bottom.setdefault("2", []).append(specific_string("nbcv",3)) 
    bottom.setdefault("2", []).append(specific_string("cvbn",4))
    bottom.setdefault("2", []).append(specific_string("nbcv",1)) 
    bottom.setdefault("2", []).append(specific_string("cvbn",2)) 
    bottom.setdefault("2", []).append(specific_string("nbcv",3)) 
    bottom.setdefault("2", []).append(specific_string("cvbn",4)) 
    bottom.setdefault("2", []).append(specific_string("nbcv",2)) 
    bottom.setdefault("2", []).append(specific_string("cvbn",3)) 
    bottom.setdefault("2", []).append(specific_string("nbcv",4)) 

    bottom.setdefault("3", []).append(specific_string("zxcvbnm,.",1)) 
    bottom.setdefault("3", []).append(specific_string("zxcvbnm,.",2)) 
    bottom.setdefault("3", []).append(specific_string("zxcvbnm,.",3)) 
    bottom.setdefault("3", []).append(specific_string("zxcvbnm,.",4))
    bottom.setdefault("3", []).append(specific_string("zxcvbnm,.",1)) 
    bottom.setdefault("3", []).append(specific_string("zxcvbnm,.",2)) 
    bottom.setdefault("3", []).append(specific_string("zxcvbnm,.",3)) 
    bottom.setdefault("3", []).append(specific_string("zxcvbnm,.",4)) 
    bottom.setdefault("3", []).append(specific_string("zxcvbnm,.",2)) 
    bottom.setdefault("3", []).append(specific_string("zxcvbnm,.",3)) 
    bottom.setdefault("3", []).append(specific_string("zxcvbnm,.",4)) 
 
bottomkey=dict({'bottomkey':bottom})

# %%
topkey={}
left={}
right={}
middle={}
top= {}
for i in range(10):
    top.setdefault("0", []).append(specific_string('qwer',1)) 
    top.setdefault("0", []).append(specific_string('qwer',2)) 
    top.setdefault("0", []).append(specific_string('rewq',3)) 
    top.setdefault("0", []).append(specific_string('ewrq',4)) 
    top.setdefault("0", []).append(specific_string('qwer',1)) 
    top.setdefault("0", []).append(specific_string('qwer',2)) 
    top.setdefault("0", []).append(specific_string('rewq',3)) 
    top.setdefault("0", []).append(specific_string('ewrq',4)) 
    top.setdefault("0", []).append(specific_string('rewq',3)) 
    top.setdefault("0", []).append(specific_string('ewrq',2)) 

for i in range(10):
    top.setdefault("1", []).append(specific_string('poiu',1)) 
    top.setdefault("1", []).append(specific_string('opiu',2)) 
    top.setdefault("1", []).append(specific_string('opiu',3)) 
    top.setdefault("1", []).append(specific_string('opiu',4)) 
    top.setdefault("1", []).append(specific_string('oiou',1)) 
    top.setdefault("1", []).append(specific_string('poui',2)) 
    top.setdefault("1", []).append(specific_string('uiop',3)) 
    top.setdefault("1", []).append(specific_string('uiop',2)) 
    top.setdefault("1", []).append(specific_string('uiop',3)) 
    top.setdefault("1", []).append(specific_string('uiop',2)) 

for i in range(10):
    top.setdefault("2", []).append(specific_string('rtyu',1)) 
    top.setdefault("2", []).append(specific_string('rtyu',2)) 
    top.setdefault("2", []).append(specific_string('rtyu',3)) 
    top.setdefault("2", []).append(specific_string('rtyu',4)) 
    top.setdefault("2", []).append(specific_string('rtyu',1)) 
    top.setdefault("2", []).append(specific_string('rtyu',2)) 
    top.setdefault("2", []).append(specific_string('rtyu',3)) 
    top.setdefault("2", []).append(specific_string('rtyu',2)) 
    top.setdefault("2", []).append(specific_string('rtyu',3)) 
    top.setdefault("2", []).append(specific_string('rtyu',2))

for i in range(10):
    top.setdefault("3", []).append(specific_string('qwertyuiop',1)) 
    top.setdefault("3", []).append(specific_string('qwertyuiop',2)) 
    top.setdefault("3", []).append(specific_string('qwertyuiop',3)) 
    top.setdefault("3", []).append(specific_string('qwertyuiop',4)) 
    top.setdefault("3", []).append(specific_string('qwertyuiop',1)) 
    top.setdefault("3", []).append(specific_string('qwertyuiop',2)) 
    top.setdefault("3", []).append(specific_string('qwertyuiop',3)) 
    top.setdefault("3", []).append(specific_string('qwertyuiop',2)) 
    top.setdefault("3", []).append(specific_string('qwertyuiop',3)) 
    top.setdefault("3", []).append(specific_string('qwertyuiop',2)) 
topkey=dict({'topkey':top})

# %%
homekey.update(bottomkey)

# %%
homekey
# Out:
# {'bottomkey': {'0': ['z',
#    'vz',
#    'zzx',
#    'xxzx',
#    'x',
#    'xv',
#    'xvx',
#    'vzxz',
#    'ccv',
#    'vxzz',
#    'x',
#    'xv',
#    'zvz',
#    'zxvz',
#    'v',
#    'vc',
#    'vzx',
#    'cvxz',
#    'xzx',
#    'zvxz',
#    'x',
#    'vc',
#    'cxz',
#    'zzcv',
#    'x',
#    'xc',
#    'vvc',
#    'vcvx',
#    'xvx',
#    'vxvz',
#    'z',
#    'cx',
#    'xcz',
#    'vxvv',
#    'x',
#    'vc',
#    'zxx',
#    'zvzv',
#    'ccx',
#    'zzcv',
#    'c',
#    'cc',
#    'cxz',
#    'cczc',
#    'x',
#    'zz',
#    'vcv',
#    'ccvz',
#    'cxz',
#    'czzv',
#    'v',
#    'cv',
#    'zzz',
#    'vcvx',
#    'x',
#    'zz',
#    'xcz',
#    'cczc',
#    'vxv',
#    'xxzc',
#    'c',
#    'cz',
#    'czz',
#    'zxvz',
#    'c',
#    'xz',
#    'zcz',
#    'cxvv',
#    'cvc',
#    'zzzc',
#    'x',
#    'cz',
#    'ccv',
#    'cccz',
#    'v',
#    'xv',
#    'xvx',
#    'xccz',
#    'xxz',
#    'vxcc',
#    'c',
#    'vz',
#    'cvc',
#    'czzv',
# ...

# %%
homekey.update(topkey)

# %%
homekey
# Out:
# {'bottomkey': {'0': ['z',
#    'vz',
#    'zzx',
#    'xxzx',
#    'x',
#    'xv',
#    'xvx',
#    'vzxz',
#    'ccv',
#    'vxzz',
#    'x',
#    'xv',
#    'zvz',
#    'zxvz',
#    'v',
#    'vc',
#    'vzx',
#    'cvxz',
#    'xzx',
#    'zvxz',
#    'x',
#    'vc',
#    'cxz',
#    'zzcv',
#    'x',
#    'xc',
#    'vvc',
#    'vcvx',
#    'xvx',
#    'vxvz',
#    'z',
#    'cx',
#    'xcz',
#    'vxvv',
#    'x',
#    'vc',
#    'zxx',
#    'zvzv',
#    'ccx',
#    'zzcv',
#    'c',
#    'cc',
#    'cxz',
#    'cczc',
#    'x',
#    'zz',
#    'vcv',
#    'ccvz',
#    'cxz',
#    'czzv',
#    'v',
#    'cv',
#    'zzz',
#    'vcvx',
#    'x',
#    'zz',
#    'xcz',
#    'cczc',
#    'vxv',
#    'xxzc',
#    'c',
#    'cz',
#    'czz',
#    'zxvz',
#    'c',
#    'xz',
#    'zcz',
#    'cxvv',
#    'cvc',
#    'zzzc',
#    'x',
#    'cz',
#    'ccv',
#    'cccz',
#    'v',
#    'xv',
#    'xvx',
#    'xccz',
#    'xxz',
#    'vxcc',
#    'c',
#    'vz',
#    'cvc',
#    'czzv',
# ...

# %%
with open('./gdrive/MyDrive/Nepali_Text_Files/home_json_object.json', 'w') as f:
  f.write(str(homekey))
